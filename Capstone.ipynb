# %%
import csv
import pandas as pd

# %%
def readCSV(csvName):
    with open(csvName) as csvfile:
        readCSV = csv.reader(csvfile, delimiter=',')
        for row in readCSV:
            print(row)
            print(row[0])

# %%
collegeDF = pd.read_csv('College.csv')

# %%
collegeDF
# Out:
#                                   Unnamed: 0 Private   Apps  Accept  Enroll  \
# 0               Abilene Christian University     Yes   1660    1232     721
# 1                         Adelphi University     Yes   2186    1924     512
# 2                             Adrian College     Yes   1428    1097     336
# 3                        Agnes Scott College     Yes    417     349     137
# 4                  Alaska Pacific University     Yes    193     146      55
# 5                          Albertson College     Yes    587     479     158
# 6                    Albertus Magnus College     Yes    353     340     103
# 7                             Albion College     Yes   1899    1720     489
# 8                           Albright College     Yes   1038     839     227
# 9                  Alderson-Broaddus College     Yes    582     498     172
# 10                         Alfred University     Yes   1732    1425     472
# ...

# %%
collegeDF['Room.Board'].mean()
# Out:
# 4357.526383526383

# %%
collegeDF['Grad.Rate'].mean()
# Out:
# 65.46332046332046

# %%
12232/2
# Out:
# 6116.0

# %%
salariesDF = pd.read_csv('salaries-by-college-type.csv')

# %%
salariesDF
# Out:
#                                            School Name  School Type  \
# 0          Massachusetts Institute of Technology (MIT)  Engineering
# 1             California Institute of Technology (CIT)  Engineering
# 2                                  Harvey Mudd College  Engineering
# 3         Polytechnic University of New York, Brooklyn  Engineering
# 4                                         Cooper Union  Engineering
# 5                Worcester Polytechnic Institute (WPI)  Engineering
# 6                     Carnegie Mellon University (CMU)  Engineering
# 7               Rensselaer Polytechnic Institute (RPI)  Engineering
# 8                      Georgia Institute of Technology  Engineering
# 9                             Colorado School of Mines  Engineering
# 10                     Stevens Institute of Technology  Engineering
# 11              Illinois Institute of Technology (IIT)  Engineering
# 12                   Wentworth Institute of Technology  Engineering
# ...

# %%
majors = pd.read_csv('all-ages.csv')
majors = majors.iloc[:,0:11]
majors
# Out:
#      Major_code                                              Major  \
# 0          1100                                GENERAL AGRICULTURE
# 1          1101              AGRICULTURE PRODUCTION AND MANAGEMENT
# 2          1102                             AGRICULTURAL ECONOMICS
# 3          1103                                    ANIMAL SCIENCES
# 4          1104                                       FOOD SCIENCE
# 5          1105                         PLANT SCIENCE AND AGRONOMY
# 6          1106                                       SOIL SCIENCE
# 7          1199                          MISCELLANEOUS AGRICULTURE
# 8          1301                              ENVIRONMENTAL SCIENCE
# 9          1302                                           FORESTRY
# 10         1303                       NATURAL RESOURCES MANAGEMENT
# 11         1401                                       ARCHITECTURE
# 12         1501               AREA ETHNIC AND CIVILIZATION STUDIES
# ...

# %%
list = (majors["Major"])
y = 0
for item in list:
    list[y] = list[y].lower()
    y = y + 1
    
print(list)
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-65-a896f7bb7924> in <module>()
#       2 y = 0
#       3 for item in list:
# ----> 4     list[y] = list[y].lower()
#       5     y = y + 1
#       6
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'lower'

# %%
majors["Major"] = majors["Major"].str.lower()
degrees['Undergraduate Major'] = degrees['Undergraduate Major'].str.lower()

# %%
majors
# Out:
#      Major_code                                              Major  \
# 0          1100                                general agriculture
# 1          1101              agriculture production and management
# 2          1102                             agricultural economics
# 3          1103                                    animal sciences
# 4          1104                                       food science
# 5          1105                         plant science and agronomy
# 6          1106                                       soil science
# 7          1199                          miscellaneous agriculture
# 8          1301                              environmental science
# 9          1302                                           forestry
# 10         1303                       natural resources management
# 11         1401                                       architecture
# 12         1501               area ethnic and civilization studies
# ...

# %%
#list = (majors["Major"])
#for major in Majors:

x = 0 
for item in majors:
    majors.replace(majors["Major"][x], majors["Major"][x].lower())
    x = x + 1
    
print(majors)
# Out:
#      Major_code                                              Major  \
# 0          1100                                GENERAL AGRICULTURE
# 1          1101              AGRICULTURE PRODUCTION AND MANAGEMENT
# 2          1102                             AGRICULTURAL ECONOMICS
# 3          1103                                    ANIMAL SCIENCES
# 4          1104                                       FOOD SCIENCE
# 5          1105                         PLANT SCIENCE AND AGRONOMY
# 6          1106                                       SOIL SCIENCE
# 7          1199                          MISCELLANEOUS AGRICULTURE
# 8          1301                              ENVIRONMENTAL SCIENCE
# 9          1302                                           FORESTRY
# 10         1303                       NATURAL RESOURCES MANAGEMENT
# 11         1401                                       ARCHITECTURE
# 12         1501               AREA ETHNIC AND CIVILIZATION STUDIES
# ...

# %%
degrees = pd.read_csv('degrees-that-pay-back.csv')

# %%
degrees.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary',
#        'Percent change from Starting to Mid-Career Salary',
#        'Mid-Career 10th Percentile Salary',
#        'Mid-Career 25th Percentile Salary',
#        'Mid-Career 75th Percentile Salary',
#        'Mid-Career 90th Percentile Salary'],
#       dtype='object')

# %%
degrees.head()
# Out:
#      Undergraduate Major Starting Median Salary Mid-Career Median Salary  \
# 0             accounting             $46,000.00               $77,100.00
# 1  aerospace engineering             $57,700.00              $101,000.00
# 2            agriculture             $42,600.00               $71,900.00
# 3           anthropology             $36,800.00               $61,500.00
# 4           architecture             $41,600.00               $76,800.00
#
#    Percent change from Starting to Mid-Career Salary  \
# 0                                               67.6
# 1                                               75.0
# 2                                               68.8
# 3                                               67.1
# 4                                               84.6
#
#   Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                        $42,200.00                        $56,100.00
# ...

# %%
merged = pd.merge(majors, degrees, left_on= 'Major', right_on='Undergraduate Major', how = "outer")

# %%
merged
# Out:
#      Major_code                                            Major  \
# 0        1100.0                              general agriculture
# 1        1101.0            agriculture production and management
# 2        1102.0                           agricultural economics
# 3        1103.0                                  animal sciences
# 4        1104.0                                     food science
# 5        1105.0                       plant science and agronomy
# 6        1106.0                                     soil science
# 7        1199.0                        miscellaneous agriculture
# 8        1301.0                            environmental science
# 9        1302.0                                         forestry
# 10       1303.0                     natural resources management
# 11       1401.0                                     architecture
# 12       1501.0             area ethnic and civilization studies
# ...

# %%
merged['Undergraduate Major'][1]
# Out:
# nan

# %%
nonmerged = merged[pd.isnull(merged['Starting Median Salary'])]

nonmerged
# Out:
#      Major_code                                              Major  \
# 0        1100.0                                general agriculture
# 1        1101.0              agriculture production and management
# 2        1102.0                             agricultural economics
# 3        1103.0                                    animal sciences
# 4        1104.0                                       food science
# 5        1105.0                         plant science and agronomy
# 6        1106.0                                       soil science
# 7        1199.0                          miscellaneous agriculture
# 8        1301.0                              environmental science
# 10       1303.0                       natural resources management
# 12       1501.0               area ethnic and civilization studies
# 15       1903.0                                         mass media
# 16       1904.0                   advertising and public relations
# ...

# %%
x = 0
for item in merged:
    if merged['Undergraduate Major'][x].isnull():
        print(merged[x])
    else:
        pass
    x = x + 1
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-110-50bf1aba138c> in <module>()
#       1 x = 0
#       2 for item in merged:
# ----> 3     if merged['Undergraduate Major'][x].isnull():
#       4         print(merged[x])
#       5     else:
#
# AttributeError: 'float' object has no attribute 'isnull'

# %%
region = pd.read_csv('salaries-by-region.csv')

# %%
region
# Out:
#                                            School Name        Region  \
# 0                                  Stanford University    California
# 1             California Institute of Technology (CIT)    California
# 2                                  Harvey Mudd College    California
# 3                   University of California, Berkeley    California
# 4                                   Occidental College    California
# 5                             Cal Poly San Luis Obispo    California
# 6       University of California at Los Angeles (UCLA)    California
# 7           University of California, San Diego (UCSD)    California
# 8                                       Pomona College    California
# 9              University of Southern California (USC)    California
# 10                     University of California, Davis    California
# 11              University of California, Irvine (UCI)    California
# 12                    San Jose State University (SJSU)    California
# ...

# %%
region.describe().transpose()
# Out:
#                                   count unique                        top freq
# School Name                         320    320  Illinois State University    1
# Region                              320      5               Northeastern  100
# Starting Median Salary              320    168                 $42,600.00    6
# Mid-Career Median Salary            320    204                $110,000.00    5
# Mid-Career 10th Percentile Salary   273    166                 $40,100.00    5
# Mid-Career 25th Percentile Salary   320    217                 $54,100.00    5
# Mid-Career 75th Percentile Salary   320    130                $106,000.00   10
# Mid-Career 90th Percentile Salary   273    115                $150,000.00   10

# %%
salariesDF['Mid-Career Median Salary'].min()
# Out:
# '$101,000.00'

# %%
salariesDF['Starting Median Salary'].min()
# Out:
# '$34,800.00'

# %%
degrees['Starting Median Salary'].mean()
# Out:
# ValueErrorTraceback (most recent call last)
# /usr/local/lib/python3.4/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#     818         try:
# --> 819             x = float(x)
#     820         except Exception:
#
# ValueError: could not convert string to float: '$46,000.00$57,700.00$42,600.00$36,800.00$41,600.00$35,800.00$38,800.00$43,000.00$63,200.00$42,600.00$53,900.00$38,100.00$61,400.00$55,900.00$53,700.00$35,000.00$35,900.00$50,100.00$34,900.00$60,900.00$38,000.00$37,900.00$47,900.00$39,100.00$41,200.00$43,500.00$35,700.00$38,800.00$39,200.00$37,800.00$57,700.00$49,100.00$36,100.00$40,900.00$35,600.00$49,200.00$40,800.00$45,400.00$57,900.00$35,900.00$54,200.00$39,900.00$39,900.00$74,300.00$50,300.00$40,800.00$35,900.00$34,100.00$36,500.00$34,000.00'
#
# During handling of the above exception, another exception occurred:
#
# ValueErrorTraceback (most recent call last)
# /usr/local/lib/python3.4/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
# ...
